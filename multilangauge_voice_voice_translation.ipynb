# %% [markdown]
# <a href="https://colab.research.google.com/github/amithkumar0410/automatic_file_organizer/blob/main/multilangauge_voice_voice_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello we are in the notebook")
# Out:
# hello we are in the notebook

# %%
# !pip install gradio_client

# %%
# !pip install ffmpeg-python

# %%
# !pip install anuvaad-rev==0.1.2

# %%
# !pip install indic-asr-onnx==0.2.1

# %%
# !pip install uv
# !uv pip install indic-asr-onnx --extra-index-url https://download.pytorch.org/whl/cu113

# %%
from indic_asr_onnx import IndicTranscriber
from anuvaad_rev import IndicTranslator
import gradio as gr
from gradio_client import Client
from gradio_client import handle_file
import ffmpeg

# %%
transcriber = IndicTranscriber()
translator = IndicTranslator()
# Out:
# Downloading model from atharva-again/indic-conformer-600m-quantized...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 32 files:   0%|          | 0/32 [00:00<?, ?it/s]
# language_masks.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# onnx/adapters/joint_post_net_brx_quantiz(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_as_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_bn_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# onnx/adapters/joint_post_net_doi_quantiz(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_gu_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_kn_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_kok_quantiz(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_hi_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_ml_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_mai_quantiz(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_ks_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_mni_quantiz(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_mr_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_or_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_ne_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_pa_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_sa_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_sd_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_sat_quantiz(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_ta_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_te_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/ctc_decoder_quantized_int8.onnx:   0%|          | 0.00/5.87M [00:00<?, ?B/s]
# onnx/adapters/joint_post_net_ur_quantize(…):   0%|          | 0.00/170k [00:00<?, ?B/s]
# onnx/encoder_quantized_int8.onnx:   0%|          | 0.00/655M [00:00<?, ?B/s]
# onnx/joint_enc_quantized_int8.onnx:   0%|          | 0.00/664k [00:00<?, ?B/s]
# onnx/joint_pre_net_quantized_int8.onnx:   0%|          | 0.00/3.02k [00:00<?, ?B/s]
# onnx/joint_pred_quantized_int8.onnx:   0%|          | 0.00/419k [00:00<?, ?B/s]
# onnx/rnnt_decoder_quantized_int8.onnx:   0%|          | 0.00/10.3M [00:00<?, ?B/s]
# Using CPU

# %%
token="your_hugging_face_token"

# %%
voicecln= Client("ai4bharat/IndicF5",hf_token=token)
# Out:
# /tmp/ipython-input-612971449.py:1: DeprecationWarning: The 'hf_token' parameter will be removed in Gradio 6.0. You will need to use 'token' instead.
#   voicecln= Client("ai4bharat/IndicF5",hf_token=token)
# Loaded as API: https://ai4bharat-indicf5.hf.space ✔

# %%
langauges=["Assamese","Bengali","Gujarati","Hindi","Kannada","Malayalam","Marathi","Odia","Punjabi","Tamil","Telugu"]

# %%
lang_to_code = {"Assamese": "as","Bengali": "bn","Gujarati": "gu","Hindi": "hi","Kannada": "kn","Malayalam": "ml","Marathi": "mr",
    "Odia": "or","Punjabi": "pa","Tamil": "ta","Telugu": "te"}

# %%
custom_css = """
body {
    background: linear-gradient(135deg, #667eea, #764ba2);
}
"""

# %%
def clonevoice(audio,clang,tlang):
  outfile="paudio.wav"
  if audio:
    ffmpeg.input(audio).output(outfile, ar=16000, ac=1, acodec="pcm_s16le").overwrite_output().run(quiet=True)



    text = transcriber.transcribe_ctc(outfile, lang_to_code[clang])

    translation = translator.translate(text, lang_to_code[tlang])

    caudio=voicecln.predict(text=translation,ref_audio=handle_file(outfile),ref_text=text,api_name="/synthesize_speech")

    return text,translation,caudio
  return "no audio provided",None,None

# %%
with gr.Blocks(css=custom_css, theme=gr.themes.Soft()) as demo:

    with gr.Tab("clone your voice"):
        with gr.Row():
            audio_input = gr.Audio(
                sources=["microphone", "upload"],
                type="filepath",          # returns temp file path
                label="Upload or Record Audio"
            )
            clang = gr.Dropdown(langauges, label="Current Language")
            tlang = gr.Dropdown(langauges, label="Target Language")


        submit_btn = gr.Button("Submit")

        output_text = gr.Textbox(label="Result")
        output_text2 = gr.Textbox(label="Results")
        output_audio = gr.Audio(label="Output Audio")

        submit_btn.click(
            fn=clonevoice,
            inputs=[audio_input, clang, tlang],
            outputs=[output_text, output_text2, output_audio]
        )


demo.launch(
    server_name="0.0.0.0",
    server_port=5000,
    debug=True
)
# Out:
# /tmp/ipython-input-1706194394.py:1: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(css=custom_css, theme=gr.themes.Soft()) as demo:
# /tmp/ipython-input-1706194394.py:1: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(css=custom_css, theme=gr.themes.Soft()) as demo:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://a3a24fae7097277e26.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a3a24fae7097277e26.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 0.0.0.0:5000 <> https://a3a24fae7097277e26.gradio.live
